# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Telco_Customer_Churn_Dataset  (1).csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# First, make sure to define df_encoded before using it
# For example, if you have a CSV file:
import pandas as pd

# Load your data
df = pd.read_csv('Telco_Customer_Churn_Dataset  (1).csv')  # Replace with your actual file path

# If you need to encode categorical variables:
# Assuming you need to encode some categorical columns
# This is just an example - adjust according to your actual data preprocessing needs
df_encoded = pd.get_dummies(df)  # or your specific encoding logic

# Now proceed with your original code
from sklearn.model_selection import train_test_split

X = df_encoded.drop("Churn", axis=1)
y = df_encoded["Churn"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape, y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 16
#      13 # Now proceed with your original code
#      14 from sklearn.model_selection import train_test_split
# ---> 16 X = df_encoded.drop("Churn", axis=1)
#      17 y = df_encoded["Churn"]
#      19 X_train, X_test, y_train, y_test = train_test_split(
#      20     X, y, test_size=0.20, random_state=42, stratify=y
#      21 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# ...
